# %% [markdown]
# ![image.png](attachment:c4af588e-cc0f-4d85-940a-6112cbb01fee.png)

# %% [markdown]
# https://github.com/FinanceData/FinanceDataReader

# %% [markdown]
# ## 파이썬 모듈 import
#
# - #### 파이썬 시스템 모듈 사용
#    - import sys
#
# - #### 넘파이와 판다스 모듈
#    - import numpy as np
#        - 선형대수를 처리하는 넘파이 모듈 사용
#    - import pandas as pd
#        - 판다스 모듈 사용하여 데이터 프레임 처리
#
# - #### 시각화 모듈
#    - import matplotlib as plt
#        - 기본 시각화 모듈
#    - import seaborn as sns
#        - 데이터 프레임을 바로 시각화할 수 있는 모듈 사용
#    - import pyechars as pyc
#        - 동적인 시각화 모듈 사용
#
# - #### 머신러닝
#    - import sklearn as sk
#        - 머신러닝을 지원하는 모듈 사용
