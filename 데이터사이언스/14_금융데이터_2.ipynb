# %% [markdown]
# # 02. 환율, 지수 등 금융 데이터 분석
#
# ## 1) 환율과 암호화페 조회

# %%
# %matplotlib inline

import FinanceDataReader as fdr 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df_USDKRW = fdr.DataReader('USD/KRW', '2020')
df_USDKRW.tail()
# Out:
#               Close     Open     High      Low  Change
# Date
# 2020-10-22  1134.74  1133.07  1137.55  1131.96  0.0019
# 2020-10-23  1127.95  1135.14  1136.94  1126.23 -0.0060
# 2020-10-26  1132.44  1128.45  1134.16  1127.06  0.0040
# 2020-10-27  1129.21  1132.51  1133.43  1124.69 -0.0029
# 2020-10-28  1136.29  1129.26  1138.61  1127.01  0.0063

# %%
df_USDKRW['Close'].plot(figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## 암호화페 원화가격
# - 빗썸: https://www.bithumb.com
#     - BTC/KRW : 비트코인 원 가격
#     - BCH/KRW : 비트코인 캐시원 가격
#     - EOS/KRW : 리플 원 가격
#     - LTC/KRW : 라이트코인 원 가격
#     - XLM/KRW : 스텔라 원 가격

# %%
df_BTCKRW = fdr.DataReader('BTC/KRW', '2020')
df_BTCKRW['Close'].plot(figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## 2) 주가지수 종목 확인

# %%
df_etf_kr = fdr.EtfListing('KR')
df_etf_kr.head()
# Out:
#    Symbol              Name
# 0  069500         KODEX 200
# 1  252670  KODEX 200선물인버스2X
# 2  102110         TIGER 200
# 3  122630        KODEX 레버리지
# 4  153130        KODEX 단기채권

# %%
df_kodex = fdr.DataReader('069500', '2020')
df_kodex.tail()
# Out:
#              Open   High    Low  Close   Volume    Change
# Date
# 2020-10-22  31445  31460  31220  31405  8665206 -0.006799
# 2020-10-23  31535  31625  31280  31520  7466985  0.003662
# 2020-10-26  31615  31725  31430  31460  8527443 -0.001904
# 2020-10-27  31235  31425  31120  31190  7759718 -0.008582
# 2020-10-28  31075  31360  30980  31355  4936547  0.005290

# %%
df_kodex['Close'].plot(figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_etf_us = fdr.EtfListing('US')
df_etf_us.head()
# Out:
#   Symbol                                     Name
# 0   UVXY   ProShares Ultra VIX Short-Term Futures
# 1    SPY                             SPDR S&P 500
# 2    XLF        Financial Select Sector SPDR Fund
# 3   SPXS  Direxion Daily Large Cap Bear 3X Shares
# 4    SLV                  iShares S&P Smallap 600

# %%
df_snp = fdr.DataReader('SPY', '2020')
df_snp.tail()
# Out:
#              Close    Open    High     Low      Volume  Change
# Date
# 2020-10-22  344.61  342.96  345.24  340.65  54890000.0  0.0055
# 2020-10-23  345.78  345.93  345.99  343.13  49140000.0  0.0034
# 2020-10-26  339.39  342.13  342.98  335.62  89710000.0 -0.0185
# 2020-10-27  338.22  339.76  340.12  337.99  64330000.0 -0.0034
# 2020-10-28  328.95  332.10  332.80  328.24  29330000.0 -0.0274

# %%
df_snp['Close'].plot(figsize=(16,5))
plt.show()

# %%
# 03. 한국의 주식 시가총액 분석
- https://github.com/FinanceData/marcap
